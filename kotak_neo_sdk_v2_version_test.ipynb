# %% [markdown]
# # Run the command when installing the package for the first time

# %%
pip install "git+https://github.com/lekshmivijayakumar22-cell/kotak_neo_api.git@1.0.0#egg=neo_api_client"

# %%
pip install --force-reinstall "git+https://github.com/lekshmivijayakumar22-cell/kotak_neo_api.git@1.0.0#egg=neo_api_client"

# %% [markdown]
# # Run the command when re-installing the package

# %%
from neo_api_client import NeoAPI

# %%
# client = NeoAPI(environment='prod', access_token=None, neo_fin_key=None, consumer_key='4a7bc1f6-25d9-40f4-87cd-ceb442b3f663')
client = NeoAPI(environment='prod', neo_fin_key=None, consumer_key='4a7bc1f6-25d9-40f4-87cd-ceb442b3f663')

#AKASH
# client = NeoAPI(environment='prod', access_token=None, neo_fin_key=None, consumer_key='68b661f4-507c-407f-a615-a69cfe3b88ee')

# %% [markdown]
# # TOTP Login

# %%
client.totp_login(mobile_number="+919567964983", ucc="XCAM1", totp='258038')

#AKASH
# client.totp_login(mobile_number="+919983735360", ucc="XP6M4", totp='595903')
# Out:
# URL--------------------> https://mis.kotaksecurities.com/login/1.0/tradeApiLogin
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..MFttogQbEL8etY2zActxHpWQEzbQNEYxN9WeXrfHA8ltkE2R6wfgDuGbNct9LJem7xOTqkxrnPxyMalF7jOJ7bKxyXR-O-WvimXnA0IRLAPgOWCWRyisY37KmDUKbUvOl9T9WT734_ELj1DQ_et8LydTNemKn5HvVHlAcAet1_CORUhdLc0rsLiPdqzSUtMf9rCTrPZsZjcAS-RqESGaSdHXrFbbyesMyyV9wRQMrnKWwRJRYNTdJAESR0iBWa6rPEmL33hbRiezjAZu0QMx5OcD4KUM3p5jl_eHEjOKF669_LAqVnOD-bWNSntfpI9aMIJDCUZlQ3CZmexVZkSsqA',
#   'sid': '0b4931ab-409b-47d4-b9b5-c534ac82be1d',
#   'rid': 'cd2fafc2-e325-4fe9-b2f7-2096fa8b8501',
#   'hsServerId': '',
# ...

# %%
client.totp_validate(mpin="690503")

#AKASH
# client.totp_validate(mpin="553200")
# Out:
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..elEhqD0gfjzDrTDxYB7qAhxhGs7qcedDV654MN9qWF7vTxHKTMD8L4CX-pUjQS_Ka2livJdvYd9Bfg4wp0aPk0CMQCALLeLDp2xDGcFC2CV6rsc9J9T7olrPbqYe4SVFV7UX38j35EegPHjJhmf4a_1F9SuYmIZPU2bffwhlYZvuL6uJ7qjD-QhydUfgLRdr_lx_9XLv3ySCMnT-1MRskzVXrhYP2x-lSgZMLM0RBEJ69FRo8KU-3Z__SSJHanwptWSr7PZuWPFOiJZ6GHjau2UOkflPn5nHLnvpbfMdSBtdT_UfBCoAr2d5wpzq24G5Deo-_SfMhiAZig38dZgVGg',
#   'sid': 'c55a5d2f-0abb-4e7f-84a6-50aeb3af1886',
#   'rid': 'cd2fafc2-e325-4fe9-b2f7-2096fa8b8501',
#   'baseUrl': 'https://cis.kotaksecurities.com',
#   'hsServerId': '',
#   'isUserPwdExpired': False,
#   'ucc': 'XCAM1',
# ...

# %% [markdown]
# # Order

# %% [markdown]
# #### Place Order

# %%
# import time

# for i in range(10):
#     start = time.time()
#     client.place_order(exchange_segment='nse_cm', product='CNC', price='37', order_type='L', quantity='1', validity='DAY', trading_symbol='ITBEES-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)
#     end = time.time()

#     print(f"Execution time of {i}: ", end - start)


order = client.place_order(exchange_segment='nse_cm', product='NRML', price='10', order_type='L', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)

# Limit Order(for investment 'product' will be either 'NRML' or 'CNC', for intraday 'product'=MIS)
# client.place_order(exchange_segment='nse_cm', product='NRML', price='10', order_type='L', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)
# client.place_order(exchange_segment='mcx_fo', product='NRML', price='150', order_type='L', quantity='100', validity='DAY', trading_symbol='CRUDEOIL17NOV255400CE', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)
# client.place_order(exchange_segment='nse_cm', product='NRML', price='21.5', order_type='L', quantity='1', validity='DAY', trading_symbol='SWISSMLTRY-EQ', transaction_type='S', amo='YES', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)


# Buy Markert Order(for investment 'product' will be either 'NRML' or 'CNC', for intraday 'product'=MIS)
# client.place_order(exchange_segment='nse_cm', product='NRML', price='0', order_type='MKT', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)
# client.place_order(exchange_segment='nse_cm', product='MTF', price='0', order_type='MKT', quantity='1', validity='DAY', trading_symbol='ITBEES-EQ', transaction_type='B', amo='YES', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)


# Sell Markert Order(for investment 'product' will be either 'NRML' or 'CNC', for intraday 'product'=MIS)
# client.place_order(exchange_segment='nse_cm', product='NRML', price='0', order_type='MKT', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='S', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='0', tag=None)

# Stop Loss Limit(for investment 'product' will be either 'NRML' or 'CNC', for intraday 'product'=MIS)
# client.place_order(exchange_segment='nse_cm', product='NRML', price='8.90', order_type='SL', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='8.85', tag=None)

# Stop Loss Market
# client.place_order(exchange_segment='nse_cm', product='NRML', price='0', order_type='SL-M', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='8.8', tag=None)

# Cover Order Market
# client.place_order(exchange_segment='nse_cm', product='CO', price='0', order_type='MKT', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='8.95', tag=None)

# Cover Order Limit
# client.place_order(exchange_segment='nse_cm', product='CO', price='8.9', order_type='L', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='8.7', tag=None)

# Bracket Order Market
# client.place_order(exchange_segment='nse_cm', product='BO', price='0', order_type='MKT', quantity='1', validity='DAY', trading_symbol='IDEA-EQ', transaction_type='B', amo='NO', disclosed_quantity='0', market_protection='0', pf='N', trigger_price='8.9', tag=None)

# Bracket Order Limit
# client.place_order(
#     exchange_segment="nse_cm",
#     product="BO",
#     price="8.6",
#     order_type="L",
#     quantity="1",
#     validity="DAY",
#     trading_symbol="IDEA-EQ",
#     transaction_type="B",
#     amo="NO",
#     disclosed_quantity="0",
#     market_protection="0",
#     pf="N",
#     trigger_price="0",
#     tag=None,
#     scrip_token=None,
#     square_off_type='Absolute',
#     stop_loss_type='Absolute',
#     stop_loss_value='0.5',
#     square_off_value='0.6',
#     last_traded_price='LTP',
#     trailing_stop_loss='N',
#     trailing_sl_value='0'
# )


# Bracket Order Stop Loss Limit
# client.place_order(
#     exchange_segment="nse_cm",
#     product="BO",
#     price="9.25",
#     order_type="SL",
#     quantity="1",
#     validity="DAY",
#     trading_symbol="IDEA-EQ",
#     transaction_type="B",
#     amo="NO",
#     disclosed_quantity="0",
#     market_protection="0",
#     pf="N",
#     trigger_price="9.15",
#     tag=None,
#     scrip_token=None,
#     square_off_type='Absolute',
#     stop_loss_type='Absolute',
#     stop_loss_value='0.3',
#     square_off_value='0.7',
#     last_traded_price='LTP',
#     trailing_stop_loss='N',
#     trailing_sl_value='0'
# )

print(order)
order_id = order.get('nOrdNo')
print(order_id)
# Out:
# {'nOrdNo': '251119000598980', 'stat': 'Ok', 'stCode': 200}
# 251119000598980

# %% [markdown]
# #### Modify Order

# %%
# Modify Limit Order
client.modify_order(order_id = order_id, price = "10.25", quantity = "2", disclosed_quantity = "0", trigger_price = "0", validity = "DAY", order_type='L')


# client.modify_order(order_id = "251116000000821", price = "10.25", quantity = "2", disclosed_quantity = "0", trigger_price = "0", validity = "DAY", order_type='L')

# Modify Stoploss Limit Order(Trigger Pending)
# client.modify_order(order_id = "250128001058189", price = "9", quantity = "2", disclosed_quantity = "0", trigger_price = "0", validity = "DAY", order_type='L')

# Modify Stoploss Limit Order(Trigger completed and order in open state)
# client.modify_order(order_id = "250106000495810", price = "7.50", quantity = "2", disclosed_quantity = "0", trigger_price = "0", validity = "DAY", order_type='L')

# Modify Cover Order Limit
# client.modify_order(order_id = "250129000421128", price = "8.88", quantity = "1", disclosed_quantity = "0", trigger_price = "8.8", validity = "DAY", order_type='L')

# Modify Bracket Order Limit
# client.modify_order(order_id = "250130001025724", price = "8.65", quantity = "2", disclosed_quantity = "0", trigger_price = "0", validity = "DAY", order_type='L')


# Modify Stoploss Market Order
# client.modify_order(order_id = "250128001059365", price = "0", quantity = "1", disclosed_quantity = "0", trigger_price = "8.85", validity = "DAY", order_type='SL-M')

# Modify Cover Order Market Order
# client.modify_order(order_id = "250129000393146", price = "0", quantity = "1", disclosed_quantity = "0", trigger_price = "8.85", validity = "DAY", order_type='SL')

# Modify Bracket Order Stop Loss Limit
# client.modify_order(order_id = "250131000107166", price = "9.20", quantity = "1", disclosed_quantity = "0", trigger_price = "9.10", validity = "DAY", order_type='SL')
# Out:
# {'Error': "The Given Order Status is rejected, So we can't proceed further",
#  'Reason': 'Adapter is Not Ready'}

# %% [markdown]
# #### Cancel Order

# %%
client.cancel_order(order_id = order_id)
# Out:
# {'stCode': 1022,
#  'errMsg': 'order is rejected',
#  'stat': 'please provide valid order number'}

# %%
client.cancel_order(order_id = order_id, amo = "YES", isVerify=False)
# Out:
# {'stCode': 1022,
#  'errMsg': 'order is rejected',
#  'stat': 'please provide valid order number'}

# %% [markdown]
# #### Cancel Cover Order

# %%
client.cancel_cover_order(order_id = order_id)
# Out:
# {'stCode': 1022,
#  'errMsg': 'order is rejected',
#  'stat': 'please provide valid order number'}

# %%
client.cancel_cover_order(order_id = order_id, amo = "YES", isVerify=False)
# Out:
# {'stCode': 1022,
#  'errMsg': 'order is rejected',
#  'stat': 'please provide valid order number'}

# %% [markdown]
# #### Cancel Bracket Order

# %%
client.cancel_bracket_order(order_id = order_id)
# Out:
# {'stCode': 1022,
#  'errMsg': 'order is rejected',
#  'stat': 'please provide valid order number'}

# %%
client.cancel_bracket_order(order_id = order_id, amo = "YES", isVerify=False)
# Out:
# {'stCode': 1022,
#  'errMsg': 'order is rejected',
#  'stat': 'please provide valid order number'}

# %% [markdown]
# # Report

# %%
client.order_report()
# Out:
# {'stat': 'Ok',
#  'data': [{'actId': 'XCAM1',
#    'algId': 'NA',
#    'algCat': 'NA',
#    'algSeqNo': 'NA',
#    'avgPrc': '0.00',
#    'brdLtQty': '1',
#    'brkClnt': '--',
#    'cnlQty': 0,
#    'coPct': 0,
#    'defMktProV': '0',
#    'dscQtyPct': '0',
#    'dscQty': 0,
#    'exUsrInfo': 'NA',
#    'exCfmTm': 'NA',
#    'exOrdId': '',
#    'expDt': 'NA',
#    'expDtSsb': '-',
#    'exSeg': 'nse_cm',
#    'fldQty': 0,
#    'boeSec': 1763565296,
#    'mktProPct': '--',
#    'mktPro': '0',
#    'mfdBy': 'NA',
#    'minQty': 0,
#    'mktProFlg': '0',
#    'noMktProFlg': '0',
#    'nOrdNo': '251119000581798',
#    'optTp': '- ',
#    'ordAutSt': 'NA',
#    'odCrt': 'NA',
#    'ordDtTm': '19-Nov-2025 20:44:56',
#    'ordEntTm': '19-Nov-2025 20:44:56',
#    'ordGenTp': 'NA',
#    'ordSrc': 'ADMINCPPAPI_NEOTRADEAPI',
#    'ordValDt': 'NA',
#    'prod': 'NRML',
#    'prc': '10.00',
#    'prcTp': 'L',
#    'qty': 1,
#    'refLmtPrc': 0,
#    'rejRsn': 'Adapter is Not Ready',
# ...

# %%
client.order_history(order_id = order_id)
# Out:
# {'data': {'stat': 'Ok',
#   'stCode': 200,
#   'data': [{'trdSym': 'IDEA-EQ',
#     'prc': '10.00',
#     'qty': 1,
#     'ordSt': 'rejected',
#     'trnsTp': 'B',
#     'prcTp': 'L',
#     'brdLtQty': 1,
#     'exch': 'NSE',
#     'exSeg': 'nse_cm',
#     'exchTmstp': '--',
#     'expDt': 'NA',
#     'tok': '14366',
#     'nOrdNo': '251119000598980',
#     'nReqId': '1',
#     'sym': 'IDEA',
#     'avgPrc': '0.00',
#     'algId': 'NA',
#     'algCat': 'NA',
#     'algSeqNo': 'NA',
#     'trgPrc': '0.00',
#     'dclQty': '0',
#     'exchOrdId': 'NA',
#     'rejRsn': 'Adapter is Not Ready',
#     'ordDur': 'DAY',
#     'prod': 'NRML',
#     'rptTp': 'NA',
#     'cstFrm': 'C',
#     'ordSrc': 'ADMINCPPAPI_NEOTRADEAPI',
#     'flDtTm': '19-Nov-2025 22:09:23',
#     'ordGenTp': '--',
#     'scripName': 'IDEA',
#     'stkPrc': '0.00',
#     'legOrdInd': 'NA',
#     'fldQty': 0,
#     'ordUsrMsg': 'NA',
#     'mfdBy': 'XX',
#     'unFldSz': 0,
#     'vendorCode': '',
# ...

# %%
client.trade_report()
# Out:
# {'stat': 'ok',
#  'stCode': 200,
#  'data': [{'actId': 'XCAM1',
#    'algCat': 'NA',
#    'algId': 'NA',
#    'avgPrc': '245.19',
#    'boeSec': 1763531610,
#    'brdLtQty': 1,
#    'brkClnt': 'NA',
#    'cstFrm': 'C',
#    'exOrdId': '1300000024021136',
#    'exp': '-',
#    'expDt': 'NA',
#    'exSeg': 'nse_cm',
#    'exTm': '19-Nov-2025 11:23:30',
#    'fldQty': 49,
#    'flDt': '19-Nov-2025',
#    'flId': '603054726',
#    'flLeg': 1,
#    'flTm': '11:23:30',
#    'minQty': 0,
#    'nOrdNo': '251119000251389',
#    'nReqId': '1',
#    'optTp': '- ',
#    'ordDur': 'NA',
#    'ordGenTp': '--',
#    'prcTp': 'L',
#    'prod': 'CNC',
#    'rmk': '--',
#    'rptTp': 'fill',
#    'series': 'EQ',
#    'stkPrc': '0.00',
#    'sym': 'WIPRO',
#    'trdSym': 'WIPRO-EQ',
#    'trnsTp': 'S',
#    'usrId': 'BRWPV7943P',
#    'genDen': '1',
#    'genNum': '1',
#    'hsUpTm': '2025/11/19 11:23:30',
#    'GuiOrdId': 'XCAM1-6a07c816-2457-427c-a160-f5c81ce92a3a',
#    'locId': '333333333333100',
# ...

# %%
client.trade_report(order_id = order_id)
# Out:
# {'stat': 'ok', 'stCode': 200}

# %%
client.positions()
# Out:
# {'stat': 'ok',
#  'stCode': 200,
#  'data': [{'actId': 'XCAM1',
#    'brdLtQty': 1,
#    'cfBuyAmt': '0.00',
#    'cfSellAmt': '0.00',
#    'cfBuyQty': '0',
#    'cfSellQty': '0',
#    'exSeg': 'nse_cm',
#    'buyAmt': '0.00',
#    'sellAmt': '12014.31',
#    'flBuyQty': '0',
#    'flSellQty': '49',
#    'prod': 'CNC',
#    'series': 'EQ',
#    'tok': '3787',
#    'trdSym': 'WIPRO-EQ',
#    'optTp': '- ',
#    'stkPrc': '0.00',
#    'type': 'NA',
#    'sym': 'WIPRO',
#    'sqrFlg': 'Y',
#    'posFlg': 'true',
#    'lotSz': '1',
#    'multiplier': '1',
#    'precision': '2',
#    'prcNum': '1',
#    'prcDen': '1',
#    'hsUpTm': '2025/11/19 11:23:30',
#    'expDt': 'NA',
#    'exp': '--',
#    'genNum': '1',
#    'genDen': '1',
#    'dscQty': '',
#    'upldPrc': '0.00',
#    'updRecvTm': 1763531610093416437}]}

# %% [markdown]
# # Portfolio

# %%
client.holdings()
# Out:
# {'data': [{'instrumentType': 'Equity',
#    'sector': 'Automobiles - LCVs/HCVs',
#    'instrumentToken': 0,
#    'commonScripCode': 'TML_COMMERCIALVEHICL',
#    'instrumentName': 'Tata Motors Ltd',
#    'quantity': 1,
#    'averagePrice': 206.42,
#    'holdingCost': 206.42,
#    'closingPrice': 325.15,
#    'mktValue': 325.15,
#    'scripId': '',
#    'isAlternateScrip': '',
#    'unrealisedGainLoss': 118.73,
#    'sqGainLoss': 0.0001,
#    'delGainLoss': 0.0001,
#    'subTotal': 0,
#    'prevDayLtp': 0,
#    'subType': '',
#    'instrumentStatus': 'ACTV',
#    'marketLot': 1,
#    'expiryDate': '',
#    'optType': '',
#    'strikePrice': '',
#    'symbol': 'TMCV',
#    'displaySymbol': '',
#    'exchangeSegment': 'nse_cm',
#    'series': '',
#    'exchangeIdentifier': '759784',
#    'sellableQuantity': 1,
#    'securityType': 'EQUITY STOCK',
#    'securitySubType': 'EQUITY STOCK',
#    'logoUrl': '',
#    'cmotCode': ''},
#   {'instrumentType': 'Equity',
# ...

# %%
client.limits(segment="ALL", exchange="ALL", product="ALL")
# Out:
# {'Category': 'CLIENT',
#  'EntityId': 'account-XCAM1',
#  'BoardLotLimit': '10000',
#  'CollateralValue': '4367.01',
#  'Collateral': '0',
#  'RmsCollateral': '0',
#  'AdhocMargin': '0',
#  'NotionalCash': '0',
#  'CdsSpreadBenefit': '0',
#  'AmountUtilizedPrsnt': '0',
#  'UnrealizedMtomPrsnt': '0',
#  'RealizedMtomPrsnt': '0',
#  'ExposureMarginPrsnt': '0',
#  'SpanMarginPrsnt': '0',
#  'NfospreadBenefit': '0',
#  'PremiumPrsnt': '0',
#  'MarginVarPrsnt': '0',
#  'MarginScripBasketPrsnt': '0',
#  'MtomWarningPrcntPrsnt': '0',
#  'MarginWarningPrcntPrsnt': '0',
#  'MtomSquareOffWarningPrcntPrsnt': '0',
#  'MarginUsed': '-12014.31',
#  'RmsPayInAmt': '0',
#  'RmsPayOutAmt': '0',
#  'Net': '16381.32',
#  'SpecialMarginPrsnt': '0',
#  'DaneLimit': '0',
#  'DeliveryMarginPresent': '0',
#  'CncSellcrdPresent': '-12014.31',
#  'CollateralValueMult': '0',
#  'AdhocLimitMult': '0',
#  'RmsCollateralMult': '0',
#  'NationalCashMult': '0',
#  'ComSpanMrgnNrmlPrsnt': '0',
# ...

# %%
client.margin_required(exchange_segment = "nse_cm", price = "15", order_type= "L", product = "NRML",   quantity = "10", instrument_token = "14366",  transaction_type = "B")
# Out:
# {'data': {'avlCash': '4367.010000',
#   'totMrgnUsd': '-11864.310000',
#   'mrgnUsd': '-12014.310000',
#   'ordMrgn': '150.000000',
#   'rmsVldtd': 'OK',
#   'reqdMrgn': '0.000000',
#   'avlMrgn': '0.000000',
#   'insufFund': '0.000000',
#   'stat': 'Ok',
#   'stCode': 200}}

# %% [markdown]
# # Scrip

# %%
client.scrip_master()
# Out:
# {'baseFolder': 'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod',
#  'filesPaths': ['https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed/cde_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed/mcx_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed/nse_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed/bse_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed/nse_com.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed-v1/nse_cm-v1.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed-v1/bse_cm-v1.csv']}

# %%
client.scrip_master(exchange_segment = "mcx_fo")
# Out:
# 'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-11-19/transformed/mcx_fo.csv'

# %%
# client.search_scrip(exchange_segment="nse_fo", symbol="IDEA", expiry="", option_type="", strike_price="")

# client.search_scrip(exchange_segment="nse_fo", symbol="IDEA", expiry="25NOV2025", option_type="", strike_price="")
# client.search_scrip(exchange_segment="nse_fo", symbol="RELIANCE", expiry="25NOV2025", option_type="", strike_price="1500")
# client.search_scrip(exchange_segment="nse_fo", symbol="IDEA", expiry="25NOV2025", option_type="", strike_price="")
# client.search_scrip(exchange_segment="nse_fo", symbol="NIFTY", expiry="18NOV2025", option_type="", strike_price="")
# client.search_scrip(exchange_segment="nse_fo", symbol="NIFTY", expiry="04NOV2025", option_type="", strike_price="26000")
# client.search_scrip(exchange_segment="nse_fo", symbol="NIFTY", expiry="02DEC2025", option_type="", strike_price="26000")
# client.search_scrip(exchange_segment="nse_fo", symbol="NIFTY", expiry="30DEC2025", option_type="", strike_price="26000")
# client.search_scrip(exchange_segment="nse_fo", symbol="FINNIFTY", expiry="25NOV2025", option_type="CE", strike_price="24650")
# client.search_scrip(exchange_segment="nse_fo", symbol="BANKNIFTY", expiry="25NOV2025", option_type="CE", strike_price="58000")
# client.search_scrip(exchange_segment="nse_fo", symbol="BANKNIFTY", expiry="30DEC2025", option_type="CE", strike_price="58000")



# client.search_scrip(exchange_segment="mcx_fo", symbol="CRUDEOIL", expiry="17NOV2025", option_type="", strike_price="")
# client.search_scrip(exchange_segment="mcx_fo", symbol="CRUDEOIL", expiry="17NOV2025", option_type="CE", strike_price="3750")
# client.search_scrip(exchange_segment="mcx_fo", symbol="CRUDEOIL", expiry="17NOV2025", option_type="CE", strike_price="5400")
# client.search_scrip(exchange_segment="mcx_fo", symbol="GOLD", expiry="26NOV2025", option_type="CE", strike_price="121400")
# client.search_scrip(exchange_segment="mcx_fo", symbol="GOLD", expiry="27JAN2026", option_type="CE", strike_price="121400")



# client.search_scrip(exchange_segment="bse_fo", symbol="SENSEX", expiry="06Nov2025", option_type="", strike_price="")
# client.search_scrip(exchange_segment="bse_fo", symbol="SENSEX", expiry="13NOV2025", option_type="CE", strike_price="83900")
# client.search_scrip(exchange_segment="bse_fo", symbol="SENSEX", expiry="18DEC2025", option_type="CE", strike_price="83900")
# client.search_scrip(exchange_segment="bse_fo", symbol="SENSEX", expiry="27NOV2025", option_type="CE", strike_price="83900")
# client.search_scrip(exchange_segment="bse_fo", symbol="BANKEX", expiry="27NOV2025", option_type="CE", strike_price="64500")

# %%
instrument_tokens = [
    {"instrument_token": "Nifty 50", "exchange_segment": "nse_cm"},
    {"instrument_token": "Nifty Bank", "exchange_segment": "nse_cm"},
    {"instrument_token": "BANKEX", "exchange_segment": "bse_cm"},
    {"instrument_token": "SENSEX", "exchange_segment": "bse_cm"}
]
client.quotes(instrument_tokens = instrument_tokens, quote_type = "ohlc")
# Out:
# [{'exchange_token': 'Nifty 50',
#   'display_symbol': 'Nifty 50-IN',
#   'exchange': 'nse_cm',
#   'ohlc': {'open': '25918.1000',
#    'high': '26074.6500',
#    'low': '25856.2000',
#    'close': '25910.0500'}},
#  {'exchange_token': 'Nifty Bank',
#   'display_symbol': 'Nifty Bank-IN',
#   'exchange': 'nse_cm',
#   'ohlc': {'open': '58908.1500',
#    'high': '59264.2500',
#    'low': '58688.5500',
#    'close': '58899.2500'}},
#  {'exchange_token': 'BANKEX',
#   'display_symbol': 'BANKEX-IN',
#   'exchange': 'bse_cm',
#   'ohlc': {'open': '66119.4000',
#    'high': '66542.3700',
#    'low': '65902.1300',
#    'close': '66102.8200'}},
#  {'exchange_token': 'SENSEX',
#   'display_symbol': 'SENSEX-IN',
#   'exchange': 'bse_cm',
#   'ohlc': {'open': '84643.7800',
#    'high': '85236.7700',
#    'low': '84525.9800',
#    'close': '84673.0200'}}]

# %% [markdown]
# # Web Sockets

# %%
def on_message(message):
    print('[Res]: ', message)

def on_error(message):
    result = message
    print('[OnError]: ', result)
    
def on_open(message):
    print('[OnOpen]: ', message)
    
def on_close(message):
    print('[OnClose]: ', message)


client.on_message = on_message  # called when message is received from websocket
client.on_error = on_error  # called when any error or exception occurs in code or websocket
client.on_close = on_close  # called when websocket connection is closed
client.on_open = on_open

# %%
instrument_tokens = [{"instrument_token": "14366", "exchange_segment": "nse_cm"}]

# %%
instrument_tokens = [{"instrument_token": "Nifty 50", "exchange_segment": "nse_cm"}]

# %%
instrument_tokens = [{"instrument_token": "14366", "exchange_segment": "nse_cm"}, {"instrument_token": "Nifty 50", "exchange_segment": "nse_cm"}]

# %%
client.subscribe(instrument_tokens = instrument_tokens, isIndex=False, isDepth=False)

# %%
import time
time.sleep(10)
# Out:
# [OnOpen]:  The Session has been Opened!
# [Res]:  {'type': 'stock_feed', 'data': [{'ftm0': '02/01/1970 22:21:56', 'dtm1': '17/03/1972 04:01:38', 'fdtm': '19/11/2025 19:20:33', 'ltt': '19/11/2025 15:59:52', 'v': '628320485', 'ltp': '10.69', 'ltq': '1', 'tbq': '0', 'tsq': '2441278', 'bp': '0.00', 'sp': '10.69', 'bq': '0', 'bs': '2441278', 'ap': '10.71', 'lo': '10.58', 'h': '10.89', 'lcl': '9.62', 'ucl': '11.75', 'yh': '11.08', 'yl': '6.12', 'op': '10.75', 'c': '10.74', 'mul': '1', 'prec': '2', 'cng': '-0.05', 'nc': '-0.47', 'to': '6729312394.35', 'name': 'sf', 'tk': '14366', 'e': 'nse_cm', 'ts': 'IDEA-EQ', 'request_type': 'SNAP'}]}

# %%
client.un_subscribe(instrument_tokens=instrument_tokens, isIndex=False, isDepth=False)
# Out:
# The Data has been Un-Subscribed

# %%
client.subscribe_to_orderfeed()

# %%
import time
time.sleep(10)
# Out:
# [Res]:  Un-Subscribed Successfully!
# [OnOpen]:  The Session has been Opened!
# [Res]:  {'type': 'order_feed', 'data': '{"ak":"ok","type":"cn","task":"cn","msg":"connected"}'}

# %%
client.unsubscribe_orderfeed()
# Out:
# [OnClose]:  The Session has been Closed!
# {'State': 'OK', 'message': 'Unsubscribed from order feed'}

# %% [markdown]
# # Logout

# %%
# client.logout()

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 20:05:38) [MSC v.1929 64 bit (AMD64)]
